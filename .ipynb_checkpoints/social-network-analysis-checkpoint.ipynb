# %%
import networkx as nx

# %%
g = nx.Graph()

# %%
g.add_node("Tom")
g.add_node("Jerry")

# %%
nx.nodes(g)
# Out:
# NodeView(('Tom', 'Jerry'))

# %%
nx.number_of_nodes(g)
# Out:
# 2

# %%
g.add_node("Tom") # need unique names

# %%
nx.nodes(g)
# Out:
# NodeView(('Tom', 'Jerry'))
